# %% [markdown]
# Quiz Questions:

# %% [markdown]
# 1.The difference between a spreadsheet like Excel is that it organizes data into rows and columns in a simple structure which is easy to use for smaller datasets. Then there are databases like MySQL that are more complex and can use multiple tables that can handle huge amounts of data. But I found that spreadsheets are better for quick calculations and simple stuff while databases are designed for like managing bigger scale data with better security and multiple users at once.
#
# 2. Some of the advantages of using a spreadsheet for health data management is that spreadsheets are super easy to learn and use and I feel like anyone can start entering data and making charts without too much training. I feel like they're great for small datasets and let you quickly do calculations and can see the data with cool features. Some disadvantages are that spreadsheets don't really work well with large datasets because they're limited in capacity and how they perform. They also can have weak security and how the data is controlled and it can get hard for multiple people to work on them at the same time.
#
# 3.The advantages of using a database for health data management is that it can handle massive amounts of data and it has built-in tools to keep the data accurate and secure. It also lets multiple users access and work with the data simultaneously. Then the disadvantages of it is that databases are way harder to learn because you need to know database design and SQL programming. They also require a lot of planning and effort to set up initially which can show how it makes them more complicated than spreadsheets.
#
# 4.Some examples of tasks that can be performed using a spreadsheet is that you can enter patient data manually and calculate basic stats like averages or sums. It can also let you create charts to visualize the data and use different formattings to show important values like high blood pressure readings. You can also sort and filter data and make pivot tables and even do simple calculations with formulas.
#
# 5. Some examples of tasks that can be performed using a database is that it’s good for managing electronic health records for thousands of patients and storing different insurance claims or if there is clinical trial data. I found that databases can handle complex situations between different types of data across multiple tables. Also databases can support lots of users accessing the same information at once with advanced security controls.
#
# 6. Some examples of tasks that can be performed using both spreadsheets and databases is that they can store and organize data and also do basic sorting and filtering while generating reports. Another useful thing is that they both can export data to CSV files and perform simple calculations or summaries. I found that both tools are useful for managing patient information and tracking research data though databases that can better handle it at a bigger scale.
#
# 7. Some examples of tasks that can be performed using neither of them is live patient monitoring needs that can be specialized in medical equipment and monitoring systems not spreadsheets or databases. Also things like medical imaging like X-rays and MRIs require PACS systems that are designed specifically for handling images. Also when there is virtual video consultations that need telehealth platforms and analyzing medical images requires special image processing software.
#
# 8.Some examples of tasks that can be performed using a spreadsheet but not a data is that spreadsheets can let you do quick calculations without any setup or needing programming knowledge so all you have to do is just type in formulas and get instant results. You can also create charts and graphs directly in the spreadsheet with features like the built-in tools.
#
# 9. Some examples of tasks that can be performed using a database and not a spreadsheet is that databases can efficiently manage millions of patient records which would completely crash if it were a spreadsheet. It can also enforce complicated situations between multiple tables and make sure the data stays consistent across all of them through normalization. The databases can support 50 or more users working on the same data simultaneously with sophisticated security controls which spreadsheets just can't do.
#
# 10. Some examples of tasks that can be performed using both is that they both can store data while also doing basic searches and filters and create summary statistics. They both can also import and export data and organize information in a structured way. The main difference is that databases do all this stuff way better when you have tons of data or lots of users.
